# %% [markdown]
# <a href="https://colab.research.google.com/github/YuliantiOenang/tryingHuggingFace/blob/main/Test_HF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip install transformers

# %%
# pip install datasets

# %%
from datasets import load_dataset

dataset = load_dataset("tweets_hate_speech_detection")

# %%
dataset['train'][0]
# Out:
# {'label': 0,
#  'tweet': '@user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run'}

# %%
from transformers import pipeline, set_seed
generator = pipeline('text-generation', model='gpt2')
set_seed(42)
generator("Hello, I'm a language model,", max_length=30, num_return_sequences=5)
# Out:
# Downloading: 100%|██████████████████████████████| 665/665 [00:00<00:00, 539kB/s]
# Downloading: 100%|███████████████████████████| 548M/548M [01:10<00:00, 7.75MB/s]
# Downloading: 100%|██████████████████████████| 1.04M/1.04M [00:02<00:00, 382kB/s]
# Downloading: 100%|████████████████████████████| 456k/456k [00:01<00:00, 312kB/s]
# Downloading: 100%|██████████████████████████| 1.36M/1.36M [00:03<00:00, 370kB/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Hello, I'm a language model, I'm writing a new language for you. But first, I'd like to tell you about the language itself"},
#  {'generated_text': "Hello, I'm a language model, and I'm trying to be as expressive as possible. In order to be expressive, it is necessary to know"},
#  {'generated_text': "Hello, I'm a language model, so I don't get much of a license anymore, but I'm probably more familiar with other languages on that"},
# ...

# %%
dataset['train'][0]
# Out:
# {'label': 0,
#  'tweet': '@user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run'}

# %%
#generator(dataset['train'][0], max_length=30, num_return_sequences=5)

# %%
dataset['train'][0]['tweet']
# Out:
# '@user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run'

# %%
generation_result = generator(dataset['train'][0]['tweet'], max_length=100, num_return_sequences=5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
generation_result[0]
# Out:
# {'generated_text': "@user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #runners_for_thewilson\n\nAnonymous 05/19/14 (Thu) 08:55:59 AM No. 62677 >>62678\n\nBut it's a little sad that there is only like 4 people who have any interest in running for office when she's literally running for that girl. But it's a little sad that there is only"}

# %%
input_text = '@user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.'
generation_result = generator(input_text, max_length=50, num_return_sequences=5)
generation_result[0]
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# {'generated_text': '@user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction. The dad is very selfish, he has a very powerful power over this kid. You have to think for yourself when you need that power.\n\n'}

# %%
input_text = 'what is your name?'
generation_result = generator(input_text, max_length=50, num_return_sequences=5)
generation_result[0]
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# {'generated_text': 'what is your name?\n\n"Lily."\n\nTears were very hard on the girl\'s face. "Gianna. Why would—"\n\n"Gianna?"\n\nGianna was taken aback at Luna\'s'}

# %%
input_text = 'what is your name?'
generation_result = generator(input_text, max_length=50, num_return_sequences=10)
generation_result[0]
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# {'generated_text': 'what is your name? Who will you be in 12 hours? Will we hear about your life? What are your dreams?" He spoke slowly as if he were going to write a letter to anyone. And he said something along the lines of: If'}

# %%
input_text = 'what is your name?'
generation_result = generator(input_text, max_length=50, num_return_sequences=2)
generation_result[0]
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# {'generated_text': "what is your name? (Optional) *Giggle* Yeah *snuggle* This is weird I want to start wearing these boots now, you know you like this. It's not exactly comfortable. And even then I can't get into my"}

# %%
input_text = 'my name is yuli'
generation_result = generator(input_text, max_length=50, num_return_sequences=2)
generation_result[0]
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# {'generated_text': "my name is yuliandal\n\nYou like your place of worship. If you prefer to become a deity\n\nyou should consider yourself free and independent\n\nYou have more control over your life than your parents.\n\nYou're the"}

# %%
input_text = 'my name is yuli'
generation_result = generator(input_text, max_length=50, num_return_sequences=5)
generation_result[0]
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# {'generated_text': 'my name is yuli. He said, "This is the man I\'d love to marry, and I need a husband who has love for my children." I said, "Yes," and he agreed. Then my mother told me—then,'}

# %%
input_text = 'my name is yuli. she'
generation_result = generator(input_text, max_length=50, num_return_sequences=5)
generation_result[0]
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# {'generated_text': "my name is yuli. she gave our son a good chance but they're bad at this stuff lol but i love us! We have been talking about this a lot but i never talked to you. (smiles) :)\n\n4."}

# %%
input_text = 'my name is yuli. she is a nurse in a hospital'
generation_result = generator(input_text, max_length=50, num_return_sequences=5)
generation_result[0]
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# {'generated_text': 'my name is yuli. she is a nurse in a hospital at Nairobi, a university in southern Kenya. we are a family here with a love and support. when i leave my old friend the idea of living in a place like this'}
