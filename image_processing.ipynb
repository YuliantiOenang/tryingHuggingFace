# %% [markdown]
# <a href="https://colab.research.google.com/github/YuliantiOenang/tryingHuggingFace/blob/main/image_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# !pip install datasets
# Out:
# Requirement already satisfied: transformers in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (4.24.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from transformers) (4.64.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from transformers) (0.13.1)
# Requirement already satisfied: numpy>=1.17 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from transformers) (1.22.1)
# Requirement already satisfied: requests in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from transformers) (2.27.1)
# Requirement already satisfied: filelock in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from transformers) (3.6.0)
# Requirement already satisfied: packaging>=20.0 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from transformers) (2022.1.18)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from transformers) (0.10.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from packaging>=20.0->transformers) (2.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from requests->transformers) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: datasets in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (2.3.2)
# Requirement already satisfied: dill<0.3.6 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from datasets) (2022.5.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from datasets) (2.27.1)
# Requirement already satisfied: multiprocess in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from datasets) (0.70.13)
# Requirement already satisfied: aiohttp in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from datasets) (3.8.1)
# Requirement already satisfied: pandas in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from datasets) (1.3.5)
# Requirement already satisfied: packaging in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from datasets) (21.3)
# Requirement already satisfied: numpy>=1.17 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from datasets) (1.22.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from datasets) (0.10.1)
# Requirement already satisfied: responses<0.19 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from datasets) (0.18.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from datasets) (8.0.0)
# Requirement already satisfied: xxhash in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from datasets) (3.0.0)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from datasets) (4.64.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: filelock in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from packaging->datasets) (2.4.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from aiohttp->datasets) (1.7.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from aiohttp->datasets) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from aiohttp->datasets) (19.1.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from pandas->datasets) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/yuliantioenang/opt/miniconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.12.0)

# %%
from transformers import AutoFeatureExtractor, ResNetForImageClassification
import torch
from datasets import load_dataset

dataset = load_dataset("ashraq/fashion-product-images-small")
bytes = dataset["train"]["image"][0]['bytes']
image = Image.open(io.BytesIO(bytes))

# dataset = load_dataset("huggingface/cats-image")
# image = dataset["test"]["image"][0]

feature_extractor = AutoFeatureExtractor.from_pretrained("microsoft/resnet-50")
model = ResNetForImageClassification.from_pretrained("microsoft/resnet-50")

inputs = feature_extractor(image, return_tensors="pt")

with torch.no_grad():
    logits = model(**inputs).logits

# model predicts one of the 1000 ImageNet classes
predicted_label = logits.argmax(-1).item()
print(model.config.id2label[predicted_label])
# Out:
# Using custom data configuration ashraq--fashion-product-images-small-909c61a107795b31
# Reusing dataset parquet (/Users/yuliantioenang/.cache/huggingface/datasets/ashraq___parquet/ashraq--fashion-product-images-small-909c61a107795b31/0.0.0/7328ef7ee03eaf3f86ae40594d46a1cec86161704e02dd19f232d81eee72ade8)
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 55.55it/s]
# pajama, pyjama, pj's, jammies

# %%
type(image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile
